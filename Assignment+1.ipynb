# %% [markdown]
# ---
#
# _You are currently looking at **version 1.1** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-social-network-analysis/resources/yPcBs) course resource._
#
# ---

# %% [markdown]
# # Assignment 1 - Creating and Manipulating Graphs
#
# Eight employees at a small company were asked to choose 3 movies that they would most enjoy watching for the upcoming company movie night. These choices are stored in the file `Employee_Movie_Choices.txt`.
#
# A second file, `Employee_Relationships.txt`, has data on the relationships between different coworkers.
#
# The relationship score has value of `-100` (Enemies) to `+100` (Best Friends). A value of zero means the two employees haven't interacted or are indifferent.
#
# Both files are tab delimited.

# %%
import networkx as nx
import pandas as pd
import numpy as np
from networkx.algorithms import bipartite


# This is the set of employees
employees = set(['Pablo',
                 'Lee',
                 'Georgia',
                 'Vincent',
                 'Andy',
                 'Frida',
                 'Joan',
                 'Claude'])

# This is the set of movies
movies = set(['The Shawshank Redemption',
              'Forrest Gump',
              'The Matrix',
              'Anaconda',
              'The Social Network',
              'The Godfather',
              'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls'])


# you can use the following function to plot graphs
# make sure to comment it out before submitting to the autograder
#def plot_graph(G, weight_name=None):
#    '''
#    G: a networkx G
#    weight_name: name of the attribute for plotting edge weights (if G is weighted)
#    '''
#    %matplotlib notebook
#    import matplotlib.pyplot as plt
#    
#    plt.figure()
#    pos = nx.spring_layout(G)
#    edges = G.edges()
#    weights = None
#    
#    if weight_name:
#        weights = [int(G[u][v][weight_name]) for u,v in edges]
#        labels = nx.get_edge_attributes(G,weight_name)
#        nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
#        nx.draw_networkx(G, pos, edges=edges, width=weights);
#    else:
#        nx.draw_networkx(G, pos, edges=edges);

# %% [markdown]
# ### Question 1
#
# Using NetworkX, load in the bipartite graph from `Employee_Movie_Choices.txt` and return that graph.
#
# *This function should return a networkx graph with 19 nodes and 24 edges*

# %%
def answer_one():
        
    G = nx.read_edgelist("Employee_Movie_Choices.txt", delimiter='\t')
    
    G.add_nodes_from(['Pablo',
                 'Lee',
                 'Georgia',
                 'Vincent',
                 'Andy',
                 'Frida',
                 'Joan',
                 'Claude'], bipartite=0)
    
    G.add_nodes_from(['The Shawshank Redemption',
              'Forrest Gump',
              'The Matrix',
              'Anaconda',
              'The Social Network',
              'The Godfather',
              'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls'], bipartite=1)
    
    
    return G# Your Answer Here
#!cat Employee_Movie_Choices.txt
#!cat Employee_Relationships.txt
answer_one()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %% [markdown]
# ### Question 2
#
# Using the graph from the previous question, add nodes attributes named `'type'` where movies have the value `'movie'` and employees have the value `'employee'` and return that graph.
#
# *This function should return a networkx graph with node attributes `{'type': 'movie'}` or `{'type': 'employee'}`*

# %%
def answer_two():
    G = nx.read_edgelist("Employee_Movie_Choices.txt", delimiter='\t')
    # Your Code Here
    G.add_nodes_from(['Pablo',
                 'Lee',
                 'Georgia',
                 'Vincent',
                 'Andy',
                 'Frida',
                 'Joan',
                 'Claude'], bipartite=0)
    
    G.add_nodes_from(['The Shawshank Redemption',
              'Forrest Gump',
              'The Matrix',
              'Anaconda',
              'The Social Network',
              'The Godfather',
              'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls'], bipartite=1)
    
    G.add_node('Pablo',type='employee') 
    G.add_node('Lee', type='employee') 
    G.add_node('Georgia', type='employee') 
    G.add_node('Vincent', type='employee') 
    G.add_node('Andy', type='employee') 
    G.add_node('Frida', type='employee') 
    G.add_node('Joan', type='employee')
    G.add_node('Claude', type='employee') 
    
    G.add_node('The Shawshank Redemption', type='movie') 
    G.add_node('Forrest Gump', type='movie') 
    G.add_node('The Matrix', type='movie') 
    G.add_node('Anaconda', type='movie') 
    G.add_node('The Social Network', type='movie') 
    G.add_node('The Godfather', type='movie') 
    G.add_node('Monty Python and the Holy Grail', type='movie') 
    G.add_node('Snakes on a Plane', type='movie') 
    G.add_node('Kung Fu Panda', type='movie') 
    G.add_node('The Dark Knight', type='movie') 
    G.add_node('Mean Girls', type='movie') 
    
    X = ['Pablo','Lee','Georgia', 'Vincent','Andy','Frida','Joan', 'Claude']
    P=bipartite.projected_graph(G,X)
    
    return G # Your Answer Here
answer_two()
# Out:
# <img src="data:image/png;base64,..." width="639.2593044181615">

# %% [markdown]
# ### Question 3
#
# Find a weighted projection of the graph from `answer_two` which tells us how many movies different pairs of employees have in common.
#
# *This function should return a weighted projected graph.*

# %%
def answer_three():
        
    # Your Code Here
    G = nx.read_edgelist("Employee_Movie_Choices.txt", delimiter='\t')
    # Your Code Here
    G.add_nodes_from(['Pablo',
                 'Lee',
                 'Georgia',
                 'Vincent',
                 'Andy',
                 'Frida',
                 'Joan',
                 'Claude'], bipartite=0)
    
    G.add_nodes_from(['The Shawshank Redemption',
              'Forrest Gump',
              'The Matrix',
              'Anaconda',
              'The Social Network',
              'The Godfather',
              'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls'], bipartite=1)
    
    G.add_node('Pablo',type='employee') 
    G.add_node('Lee', type='employee') 
    G.add_node('Georgia', type='employee') 
    G.add_node('Vincent', type='employee') 
    G.add_node('Andy', type='employee') 
    G.add_node('Frida', type='employee') 
    G.add_node('Joan', type='employee')
    G.add_node('Claude', type='employee') 
    
    G.add_node('The Shawshank Redemption', type='movie') 
    G.add_node('Forrest Gump', type='movie') 
    G.add_node('The Matrix', type='movie') 
    G.add_node('Anaconda', type='movie') 
    G.add_node('The Social Network', type='movie') 
    G.add_node('The Godfather', type='movie') 
    G.add_node('Monty Python and the Holy Grail', type='movie') 
    G.add_node('Snakes on a Plane', type='movie') 
    G.add_node('Kung Fu Panda', type='movie') 
    G.add_node('The Dark Knight', type='movie') 
    G.add_node('Mean Girls', type='movie') 
    
    X = ['Pablo','Lee','Georgia', 'Vincent','Andy','Frida','Joan', 'Claude']
    X1 = ['The Shawshank Redemption','Forrest Gump', 'The Matrix', 'Anaconda', 'The Social Network', 'The Godfather', 'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls']
    B = bipartite.weighted_projected_graph(G,X) 
    return B# Your Answer Here
answer_three()
# Out:
# [('Pablo', 'Frida', {'weight': 2}),
#  ('Pablo', 'Vincent', {'weight': 1}),
#  ('Pablo', 'Andy', {'weight': 1}),
#  ('Lee', 'Andy', {'weight': 1}),
#  ('Lee', 'Joan', {'weight': 3}),
#  ('Georgia', 'Andy', {'weight': 1}),
#  ('Georgia', 'Claude', {'weight': 3}),
#  ('Vincent', 'Frida', {'weight': 2}),
#  ('Andy', 'Frida', {'weight': 1}),
#  ('Andy', 'Claude', {'weight': 1}),
#  ('Andy', 'Joan', {'weight': 1})]

# %% [markdown]
# ### Question 4
#
# Suppose you'd like to find out if people that have a high relationship score also like the same types of movies.
#
# Find the Pearson correlation ( using `DataFrame.corr()` ) between employee relationship scores and the number of movies they have in common. If two employees have no movies in common it should be treated as a 0, not a missing value, and should be included in the correlation calculation.
#
# *This function should return a float.*

# %%
def answer_four():
    #G_df = pd.read_csv('Employee_Movie_Choices.txt', delim_whitespace=True, 
                   #header=None, names=['employee', 'movie'])
    #G_m = nx.from_pandas_dataframe(G_df, 'employee', 'movie')
    #G_m.add_nodes_from(employee, bipartite = 0, type='employee')
    #G_m.add_nodes_from(movie, bipartite = 1, type='movie')
    G_m = nx.read_edgelist("Employee_Movie_Choices.txt", delimiter='\t')
    G_m.add_nodes_from(['Pablo',
                 'Lee',
                 'Georgia',
                 'Vincent',
                 'Andy',
                 'Frida',
                 'Joan',
                 'Claude'], bipartite=0)
    
    G_m.add_nodes_from(['The Shawshank Redemption',
              'Forrest Gump',
              'The Matrix',
              'Anaconda',
              'The Social Network',
              'The Godfather',
              'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls'], bipartite=1)
    G_m.add_node('Pablo',type='employee') 
    G_m.add_node('Lee', type='employee') 
    G_m.add_node('Georgia', type='employee') 
    G_m.add_node('Vincent', type='employee') 
    G_m.add_node('Andy', type='employee') 
    G_m.add_node('Frida', type='employee') 
    G_m.add_node('Joan', type='employee')
    G_m.add_node('Claude', type='employee') 
    
    G_m.add_node('The Shawshank Redemption', type='movie') 
    G_m.add_node('Forrest Gump', type='movie') 
    G_m.add_node('The Matrix', type='movie') 
    G_m.add_node('Anaconda', type='movie') 
    G_m.add_node('The Social Network', type='movie') 
    G_m.add_node('The Godfather', type='movie') 
    G_m.add_node('Monty Python and the Holy Grail', type='movie') 
    G_m.add_node('Snakes on a Plane', type='movie') 
    G_m.add_node('Kung Fu Panda', type='movie') 
    G_m.add_node('The Dark Knight', type='movie') 
    G_m.add_node('Mean Girls', type='movie') 
    
    X = ['Pablo','Lee','Georgia', 'Vincent','Andy','Frida','Joan', 'Claude']
    B_m = bipartite.weighted_projected_graph(G_m,X) 
    df_mw = pd.DataFrame(B_m.edges(data=True), columns=['employee1', 'employee2', 'weight'])
    df_mw['weight'] = df_mw['weight'].map(lambda x: x['weight'])
    df_mw2 = df_mw.copy()
    df_mw2.rename(columns={'employee1': 'employee2', 'employee2': 'employee1'}, inplace=True)
    df_common_movies = pd.concat([df_mw, df_mw2], ignore_index=True)
    df_common_movies.sort_values(by = 'employee1') 
    
    df_r = pd.read_csv('Employee_Relationships.txt', delim_whitespace=True, 
                   header=None, names=['employee1', 'employee2', 'r'])
    
    #df_join = df_r.join(df_mw, )
    df_merged = pd.merge(df_r, df_common_movies, how='left')
    df_merged['weight'].fillna(value=0, inplace=True)
    correlation_score = df_merged['weight'].corr(df_merged['r'])
    
    # Your Code Here
    # Your Code Here
    
    return correlation_score #correlation_score#G_r.edges(data=True)# Your Answer Here
answer_four()
# Out:
# 0.78839622217334737
